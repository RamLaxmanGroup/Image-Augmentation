# %%
from imgaug import augmenters
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
image_org = cv2.imread("D:\\Anaconda\\Analog Meter\\generator data\\Data generation\\base\\50\\Temp-50-1.png")

# %%
image_org.shape
# Out:
# (1810, 1788, 3)

# %%
plt.imshow(image_org)

# %%
seq_aug = augmenters.Sequential([
    augmenters.blur.MotionBlur(k=7)
    
])

# %%
image_aug1 = seq_aug(images=image_org)
plt.imshow(image_aug1)
